# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
lst = [2,5,6,7,8]

plt.plot(lst)

# %%
df=pd.read_csv("Used_Bikes.csv")
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
plt.plot(df["price"])

# %%
lst1=[2,3,4,5,2]
lst2=[6,4,6,4,4]

plt.scatter(lst1,lst2)

# %%
plt.scatter(x=df['age'],y=df['price'])

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             29964
# Second Owner             2564
# Third Owner               108
# Fourth Owner Or More       12
# Name: count, dtype: int64

# %%
label=list(df['owner'].value_counts().keys())
label
# Out:
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']

# %%
value= list(df['owner'].value_counts().values)
value
# Out:
# [29964, 2564, 108, 12]

# %%
plt.bar(label,value)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(label,value)
plt.xticks(rotation=60)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
label=list(df['brand'].value_counts().keys())
value= list(df['brand'].value_counts().values)
plt.bar(label,value)
plt.bar(label,value)
plt.xticks(rotation=60)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(df['age'],edgecolor='grey')  #histogram
plt.show()

# %%
bin=[0,5,10,15,20]
plt.hist(df['age'],bins=bin,edgecolor='black',color='pink')  #histogram
plt.show()
